# %% [markdown]
# # Gensim Word2Vec Tutorial

# %% [markdown]
# <img src="https://images.freeimages.com/images/large-previews/2b9/letters-1-yes-1188348.jpg" alt="drawing" width="350"/>

# %% [markdown]
# # Motivation
#
# As I started working at [Supportiv](http://www.supportiv.com), the support network for instant peer support, a few months ago, I began looking into Language Models and Word2Vec particularly. A python native, I naturally decided to focus on Gensim's implementation of Word2Vec, and went on to look for tutorials on the web. As all good data scientists, I directly applied and reproduced the code samples from multiple website. Confused and often disappointed by the results I got, I went deeper and deeper, from stackoverflow threads, to Gensim's Google Groups, onto the documentation of the library, to try and understand what went wrong in my approach. After weeks of hard labor, I finally managed to get decent results, but I was frustrated by these online tutorials which were, for the most part, misleading.
#
# What troubled me the most in these online tutorials was their mismanagement of the model training: the code worked, and I got results which appeared to be decent at first, but the more I looked into them, the more disturbing they were. I wasted a lot of time figuring out what was wrong.
#
# Another issue I had with these tutorials was the data preparation step: too often, the authors chose to load an existing preprocessed dataset, use a toy example or skip this part. However, I always thought that one of the most important parts of the creation of a Word2Vec model was then missing. During my experimentations, I noticed that lemmatizing the sentences or looking for phrases/bigrams in them had a big impact over the results and performance of my models. Though the influence of the preprocessing varies with each dataset and application, I thought I would include the data preparation steps in this tutorial and use the great spaCy library along with it.
#
# I am not the only one annoyed by some of these [issues](https://groups.google.com/d/msg/gensim/jom4JFt7EV8/y5fjhupbAgAJ), so I decided to write my own tutorial.
#
# I do not pledge that it is perfect, nor the best way to implement Word2Vec, simply that it is better than a good chunk of what is out there 😉

# %% [markdown]
# # Plan
#
# 1. [Briefing about Word2Vec](#Briefing-about-Word2Vec:)
#     * [Purpose of the tutorial](#Purpose-of-the-tutorial:)
#     * [Brief explanation](#Brief-explanation:)
#
# 2. [Getting Started](#Getting-Started)
#     * [Setting up the environment](#Setting-up-the-environment:)
#     * [The data](#The-data:)
# 3. [Preprocessing](#Preprocessing)
#     * [Cleaning](#Cleaning)
#     * [Bigrams](#Bigrams)
#     * [Most frequent words](#Most-Frequent-Words)
#
# 4. [Training the Model](#Training-the-model)
#     * [Gensim Word2Vec Implementation](#Gensim-Word2Vec-Implementation:)
#     * [Why I seperate the training of the model in 3 steps](#Why-I-seperate-the-training-of-the-model-in-3-steps:)
#     * [Training the model](#Training-the-model)
#         * [The parameters](#The-parameters)
#         * [Building the vocabulary table](#Building-the-Vocabulary-Table)
#         * [Training of the model](#Training-of-the-model)
#         * [Saving the model](#Saving-the-model:)
# 5. [Exploring the Model](#Exploring-the-model)
#     * [Most similar to](#Most-similar-to:)
#     * [Similarities](#Similarities:)
#     * [Odd-one-out](#Odd-One-Out:)
#     * [Analogy difference](#Analogy-difference:)
#     * [t-SNE visualizations](#t-SNE-visualizations:)
#         * [10 Most similar words vs. 8 Random words](#10-Most-similar-words-vs.-8-Random-words:)
#         * [10 Most similar words vs. 10 Most dissimilar](#10-Most-similar-words-vs.-10-Most-dissimilar:)
#         * [10 Most similar words vs. 11th to 20th Most similar words](#10-Most-similar-words-vs.-11th-to-20th-Most-similar-words:)
# 6. [Final Thoughts](#Final-Thoughts)
# 7. [Material for more in depths understanding](#Material-for-more-in-depths-understanding:)
# 8. [Acknowledgements](#Acknowledgements)
# 9. [References](#References:)
# 10. [End](#End)

# %% [markdown]
# # Briefing about Word2Vec:
#
# <img src="http://mccormickml.com/assets/word2vec/skip_gram_net_arch.png" alt="drawing" width="550"/>
#
# [[1]](#References:)
#
#
# ## Purpose of the tutorial:
# As I said before, this tutorial focuses on the right use of the Word2Vec package from the Gensim libray; therefore, I am not going to explain the concepts and ideas behind Word2Vec here. I am simply going to give a very brief explanation, and provide you with links to good, in depth tutorials.
#
# ## Brief explanation:
#
# Word2Vec was introduced in two [papers](#Material-for-more-in-depths-understanding:) between September and October 2013, by a team of researchers at Google. Along with the papers, the researchers published their implementation in C. The Python implementation was done soon after the 1st paper, by [Gensim](https://radimrehurek.com/gensim/index.html).
#
# The underlying assumption of Word2Vec is that two words sharing similar contexts also share a similar meaning and consequently a similar vector representation from the model. For instance: "dog", "puppy" and "pup" are often used in similar situations, with similar surrounding words like "good", "fluffy" or "cute", and according to Word2Vec they will therefore share a similar vector representation.<br>
#
# From this assumption, Word2Vec can be used to find out the relations between words in a dataset, compute the similarity between them, or use the vector representation of those words as input for other applications such as text classification or clustering.
#
# # Getting Started
#
# ## Setting up the environment:
#
# `python==3.6.3`
#
# Libraries used:
#  * `xlrd==1.1.0`: https://pypi.org/project/xlrd/
#  * `spaCy==2.0.12`: https://spacy.io/usage/
#  * `gensim==3.4.0`: https://radimrehurek.com/gensim/install.html
#  * `scikit-learn==0.19.1`: http://scikit-learn.org/stable/install.html
#  * `seaborn==0.8`: https://seaborn.pydata.org/installing.html

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/44/Logo_The_Simpsons.svg" alt="drawing" width="400"/>
#
# ## The data:
# I chose to play with the script from the Simpsons, both because I love the Simpsons and because with more than 150k lines of dialogues, the dataset was substantial!
#
# This dataset contains the characters, locations, episode details, and script lines for approximately 600 Simpsons episodes, dating back to 1989. It can be found here: https://www.kaggle.com/ambarish/fun-in-text-mining-with-simpsons/data (~25MB)

# %% [markdown]
# # Preprocessing
#
# We keep only two columns:
# * `raw_character_text`: the character who speaks (can be useful when monitoring the preprocessing steps)
# * `spoken_words`: the raw text from the line of dialogue
#
# We do not keep `normalized_text` because we want to do our own preprocessing.
#
# You can find the resulting file here: https://www.kaggle.com/pierremegret/dialogue-lines-of-the-simpsons

# %%
df = pd.read_csv('simpsons_dataset.csv')
df.shape
# Out:
# (158314, 2)

# %%
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %% [markdown]
# The missing values comes from the part of the script where something happens, but with no dialogue. For instance "(Springfield Elementary School: EXT. ELEMENTARY - SCHOOL PLAYGROUND - AFTERNOON)"

# %%
df.isnull().sum()
# Out:
# raw_character_text    17814
# spoken_words          26459
# dtype: int64

# %% [markdown]
# Removing the missing values:

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# raw_character_text    0
# spoken_words          0
# dtype: int64

# %% [markdown]
# ## Cleaning:
# We are lemmatizing and removing the stopwords and non-alphabetic characters for each line of dialogue.

# %%
nlp = spacy.load('en', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)
    
print(df['spoken_words'].values)
# Out:
# ["No, actually, it was a little of both. Sometimes when a disease is in all the magazines and all the news shows, it's only natural that you think you have it."
#  "Where's Mr. Bergstrom?"
#  "I don't know. Although I'd sure like to talk to him. He didn't touch my lesson plan. What did he teach you?"
#  ... 'Psy-cho-so-ma-tic.' 'Does that mean you were crazy?'
#  'No, that means she was faking it.']

# %% [markdown]
# Removes non-alphabetic characters:

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['spoken_words'])

# %% [markdown]
# Taking advantage of spaCy .pipe() attribute to speed-up the cleaning process:

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 1.08 mins

# %% [markdown]
# Put the results in a DataFrame to remove missing values and duplicates:

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (92412, 1)

# %% [markdown]
# ## Bigrams:
# We are using Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences.
# https://radimrehurek.com/gensim/models/phrases.html
#
# The main reason we do this is to catch words like "mr_burns" or "bart_simpson" !

# %%
from gensim.models.phrases import Phrases, Phraser

# %% [markdown]
# As `Phrases()` takes a list of list of words as input:

# %%
sent = [row.split() for row in df_clean['clean']]

# %% [markdown]
# Creates the relevant phrases from the list of sentences:

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# INFO - 09:32:29: collecting all words and their counts
# INFO - 09:32:29: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 09:32:29: PROGRESS: at sentence #10000, processed 67396 words and 50551 word types
# INFO - 09:32:29: PROGRESS: at sentence #20000, processed 140465 words and 95808 word types
# INFO - 09:32:29: PROGRESS: at sentence #30000, processed 207950 words and 132011 word types
# INFO - 09:32:30: PROGRESS: at sentence #40000, processed 270207 words and 164407 word types
# INFO - 09:32:30: PROGRESS: at sentence #50000, processed 334085 words and 196195 word types
# INFO - 09:32:30: PROGRESS: at sentence #60000, processed 400877 words and 228659 word types
# INFO - 09:32:30: PROGRESS: at sentence #70000, processed 467802 words and 260712 word types
# INFO - 09:32:30: PROGRESS: at sentence #80000, processed 534361 words and 292095 word types
# INFO - 09:32:30: PROGRESS: at sentence #90000, processed 602037 words and 321944 word types
# INFO - 09:32:30: collected 328658 word types from a corpus of 618920 words (unigram + bigrams) and 92412 sentences
# INFO - 09:32:30: using 328658 counts as vocab in Phrases<0 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>

# %% [markdown]
# The goal of Phraser() is to cut down memory consumption of Phrases(), by discarding model state not strictly needed for the bigram detection task:

# %%
bigram = Phraser(phrases)
# Out:
# INFO - 09:32:30: source_vocab length 328658
# INFO - 09:32:33: Phraser built with 127 127 phrasegrams

# %% [markdown]
# Transform the corpus based on the bigrams detected:

# %%
sentences = bigram[sent]

print(sentences)
# Out:
# <gensim.interfaces.TransformedCorpus object at 0x1a289434e0>

# %% [markdown]
# ## Most Frequent Words:
# Mainly a sanity check of the effectiveness of the lemmatization, removal of stopwords, and addition of bigrams.

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)

print(word_freq)
# Out:
# defaultdict(<class 'int'>, {'actually': 432, 'little': 2130, 'disease': 46, 'magazine': 125, 'news': 252, 'show': 213, 'be': 35473, 'natural': 78, 'think': 3765, 'mr': 808, 'bergstrom': 18, 'not': 14093, 'know': 4998, 'would': 1208, 'sure': 1250, 'like': 5322, 'talk': 987, 'touch': 197, 'lesson': 165, 'plan': 309, 'teach': 329, 'life': 1244, 'worth': 144, 'live': 762, 'poll': 20, 'open': 432, 'end': 469, 'recess': 11, 'case': 220, 'decide': 136, 'thought': 119, 'will': 6281, 'final': 108, 'statement': 21, 'martin': 121, 'leave': 1061, 'victory': 31, 'party': 428, 'slide': 48, 'hey': 3753, 'move': 170, 'morning': 309, 'new': 1336, 'job': 599, 'take': 914, 'copernicus': 5, 'costume': 65, 'train': 136, 'capital_city': 40, 'traditional': 19, 'environmentally': 3, 'sound': 301, 'yes': 1158, 'backbone': 7, 'country': 248, 'leland': 1, 'stanford': 5, 'drive': 439, 'golden': 53, 'spike': 15, 'promontory': 1, 'point': 387, 'thank': 1334, 'vote': 168, 'man': 2721, 'voting': 9, "'s": 5210, 'geek': 21, 'get': 3130, 'right': 3576, 'girl': 699, 'sweat': 35, 'long': 710, 'couple': 206, 'people': 1536, 'milhouse': 523, 'bart': 2801, 'recount': 3, 'want': 3250, 'way': 1725, 'mister': 117, 'president': 265, 'board': 89, 'track': 78, 'afternoon': 87, 'delight': 20, 'come': 3236, 'shelbyville': 86, 'parkville': 1, 'oh': 6646, 'mean': 1304, 'go': 2846, 'ah': 854, 'sorry': 1306, 'lisa': 1786, 'substitute': 24, 'teacher': 232, 'fraud': 32, 'today': 749, 'wear': 404, 'gym': 55, 'short': 164, 'tomorrow': 366, 'speak': 239, 'french': 90, 'pretend': 97, 'run': 591, 'band': 152, 'saw': 13, 'god': 643, 'good': 3748, 'true': 352, 'lie': 387, 'need': 1850, 'project': 92, 'problem': 467, 'middle': 97, 'class': 331, 'anybody': 134, 'care': 563, 'abandon': 48, 'understand': 307, 'miss': 619, 'feel': 1072, 'rely': 8, 'guess': 757, 'mind': 407, 'alongside': 4, 'speed': 64, 'goodbye': 154, 'honey': 539, 'okay': 1957, 'read': 483, 'note': 102, 'throw': 369, 'big': 1168, 'bash': 22, 'champagne': 33, 'musician': 24, 'holy': 89, 'bad': 1088, 'thing': 2117, 'happen': 694, 'alright': 54, 'allright': 2, 'spill': 37, 'milk': 128, 'mopey': 1, 'tell': 1958, 'father': 678, 'forever': 229, 'glad': 235, 'cry': 164, 'hate': 360, 'base': 109, 'emotion': 17, 'sir': 943, 'baboon': 16, 'realize': 185, 'say': 1645, 'whoa': 313, 'somebody': 202, 'bind': 31, 'day': 1795, 'believe': 760, 'hear': 1023, 'marge': 2385, 'call': 603, 'stupid': 607, 'ugliest': 3, 'smelly': 11, 'ape': 54, 'homer': 3059, 'allow': 128, 'hurt': 333, 'feeling': 193, 'little_girl': 146, 'upstairs': 34, 'confidence': 26, 'shake': 109, 'happy': 613, 'faith': 73, 'daddy': 345, 'hold': 468, 'look': 3468, 'forgive': 120, 'maybe': 1064, 'help': 1096, 'lose': 629, 'special': 342, 'lucky': 162, 'roof': 63, 'child': 808, 'time': 2635, 'bed': 285, 'lot': 826, 'probably': 213, 'place': 823, 'food': 383, 'real': 676, 'guy': 1616, 'serve': 117, 'drink': 422, 'explain': 118, 'fix': 151, 'doll': 91, 'house': 835, 'monkey': 217, 'work': 1424, 'nail': 59, 'tail': 46, 'dad': 2055, 'matter': 257, 'son': 971, 'lewi': 21, 'money': 966, 'neat': 22, 'ball': 284, 'world': 802, 'series': 69, 'huh': 576, 'let': 1367, 'baby': 915, 'bottle': 132, 'motto': 8, 'moly': 10, 'parenting': 17, 'sleep': 391, 'maggie': 497, 'let_-PRON-': 1680, 'roll': 214, 'mmm': 148, 'hor': 8, 'doover': 1, 'promise': 276, 'eat': 983, 'have': 3208, 'go_to': 2543, 'pay': 631, 'friend': 871, 'invite': 104, 'home': 1058, 'mom': 1158, 'witty': 13, 'banter': 2, 'sophisticated': 18, 'adult': 121, 'yeah': 2380, 'fun': 590, 'old': 1263, 'better': 340, 'hmmm': 181, 'mmmm': 58, 'gag': 31, 'ice': 106, 'cub': 9, 'record': 163, 'bartender': 36, 'ph': 6, 'd': 297, 'mixology': 1, 'try': 1043, 'flander': 393, 'planter': 1, 'punch': 121, 'alcohol': 65, 'au': 14, 'contraire': 3, 'simpson': 1004, 'shot': 121, 'rum': 14, 'jigger': 3, 'bourbon': 11, 'dab': 6, 'roo': 3, 'creme': 6, 'de': 160, 'cassis': 1, 'flavor': 46, 'warm': 90, 'sense': 116, 'ssslurr': 1, 'shpeech': 1, 'easy': 345, 'a ...

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['be', 'not', 'oh', 'will', 'like', "'s", 'know', 'think', 'hey', 'good']

# %% [markdown]
# # Training the model
# ## Gensim Word2Vec Implementation:
# We use Gensim implementation of word2vec: https://radimrehurek.com/gensim/models/word2vec.html

# %%
import multiprocessing

from gensim.models import Word2Vec

# %% [markdown]
# ## Why I seperate the training of the model in 3 steps:
# I prefer to separate the training in 3 distinctive steps for clarity and monitoring.
# 1. `Word2Vec()`:
# >In this first step, I set up the parameters of the model one-by-one. <br>I do not supply the parameter `sentences`, and therefore leave the model uninitialized, purposefully.
# 2. `.build_vocab()`:
# >Here it builds the vocabulary from a sequence of sentences and thus initialized the model. <br>With the loggings, I can follow the progress and even more important, the effect of `min_count` and `sample` on the word corpus. I noticed that these two parameters, and in particular `sample`, have a great influence over the performance of a model. Displaying both allows for a more accurate and an easier management of their influence.
# 3. `.train()`:
# >Finally, trains the model.<br>
# The loggings here are mainly useful for monitoring, making sure that no threads are executed instantaneously.

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
print(cores)
# Out:
# 4

# %% [markdown]
# ## The parameters:
#
# * `min_count` <font color='purple'>=</font> <font color='green'>int</font> - Ignores all words with total absolute frequency lower than this - (2, 100)
#
#
# * `window` <font color='purple'>=</font> <font color='green'>int</font> - The maximum distance between the current and predicted word within a sentence. E.g. `window` words on the left and `window` words on the left of our target - (2, 10)
#
#
# * `size` <font color='purple'>=</font> <font color='green'>int</font> - Dimensionality of the feature vectors. - (50, 300)
#
#
# * `sample` <font color='purple'>=</font> <font color='green'>float</font> - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial.  - (0, 1e-5)
#
#
# * `alpha` <font color='purple'>=</font> <font color='green'>float</font> - The initial learning rate - (0.01, 0.05)
#
#
# * `min_alpha` <font color='purple'>=</font> <font color='green'>float</font> - Learning rate will linearly drop to `min_alpha` as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
#
#
# * `negative` <font color='purple'>=</font> <font color='green'>int</font> - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
#
#
# * `workers` <font color='purple'>=</font> <font color='green'>int</font> - Use these many worker threads to train the model (=faster training with multicore machines)

# %%
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %% [markdown]
# ## Building the Vocabulary Table:
# Word2Vec requires us to build the vocabulary table (simply digesting all the words and filtering out the unique words, and doing some basic counts on them):

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 09:32:35: collecting all words and their counts
# INFO - 09:32:35: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 09:32:36: PROGRESS: at sentence #10000, processed 65193 words, keeping 9096 word types
# INFO - 09:32:36: PROGRESS: at sentence #20000, processed 136024 words, keeping 13916 word types
# INFO - 09:32:36: PROGRESS: at sentence #30000, processed 201577 words, keeping 16865 word types
# INFO - 09:32:36: PROGRESS: at sentence #40000, processed 262082 words, keeping 19506 word types
# INFO - 09:32:36: PROGRESS: at sentence #50000, processed 324069 words, keeping 21758 word types
# INFO - 09:32:37: PROGRESS: at sentence #60000, processed 388895 words, keeping 23910 word types
# INFO - 09:32:37: PROGRESS: at sentence #70000, processed 454042 words, keeping 25876 word types
# INFO - 09:32:37: PROGRESS: at sentence #80000, processed 518929 words, keeping 27769 word types
# INFO - 09:32:37: PROGRESS: at sentence #90000, processed 584755 words, keeping 29345 word types
# INFO - 09:32:37: collected 29673 word types from a corpus of 601119 raw words and 92412 sentences
# INFO - 09:32:37: Loading a fresh vocabulary
# INFO - 09:32:37: min_count=20 retains 3375 unique words (11% of original 29673, drops 26298)
# INFO - 09:32:37: min_count=20 leaves 515089 word corpus (85% of original 601119, drops 86030)
# INFO - 09:32:37: deleting the raw counts dictionary of 29673 items
# INFO - 09:32:37: sample=6e-05 downsamples 1080 most-common words
# INFO - 09:32:37: downsampling leaves estimated 219321 word corpus (42.6% of prior 515089)
# INFO - 09:32:37: estimated required memory for 3375 words and 300 dimensions: 9787500 bytes
# INFO - 09:32:37: resetting layer weights
# Time to build vocab: 0.04 mins

# %% [markdown]
# ## Training of the model:
# _Parameters of the training:_
# * `total_examples` <font color='purple'>=</font> <font color='green'>int</font> - Count of sentences;
# * `epochs` <font color='purple'>=</font> <font color='green'>int</font> - Number of iterations (epochs) over the corpus - [10, 20, 30]

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 09:32:38: training model with 3 workers on 3375 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2
# INFO - 09:32:39: EPOCH 1 - PROGRESS: at 42.87% examples, 93756 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:40: EPOCH 1 - PROGRESS: at 93.44% examples, 101184 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:40: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:40: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:40: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:40: EPOCH - 1 : training on 601119 raw words (219268 effective words) took 2.1s, 102740 effective words/s
# INFO - 09:32:41: EPOCH 2 - PROGRESS: at 48.35% examples, 102590 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:42: EPOCH 2 - PROGRESS: at 95.04% examples, 101847 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:42: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:42: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:42: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:42: EPOCH - 2 : training on 601119 raw words (219459 effective words) took 2.1s, 103896 effective words/s
# INFO - 09:32:43: EPOCH 3 - PROGRESS: at 48.35% examples, 104740 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:44: EPOCH 3 - PROGRESS: at 98.21% examples, 107086 words/s, in_qsize 3, out_qsize 0
# INFO - 09:32:44: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:44: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:44: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:44: EPOCH - 3 : training on 601119 raw words (218941 effective words) took 2.0s, 108220 effective words/s
# INFO - 09:32:45: EPOCH 4 - PROGRESS: at 44.72% examples, 95619 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:46: EPOCH 4 - PROGRESS: at 91.80% examples, 99162 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:46: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:46: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:46: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:46: EPOCH - 4 : training on 601119 raw words (219933 effective words) took 2.2s, 100075 effective words/s
# INFO - 09:32:47: EPOCH 5 - PROGRESS: at 39.12% examples, 86625 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:48: EPOCH 5 - PROGRESS: at 84.97% examples, 91510 words/s, in_qsize 1, out_qsize 0
# INFO - 09:32:48: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:48: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:49: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:49: EPOCH - 5 : training on 601119 raw words (219201 effective words) took 2.5s, 88728 effective words/s
# INFO - 09:32:50: EPOCH 6 - PROGRESS: at 39.12% examples, 86336 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:51: EPOCH 6 - PROGRESS: at 88.44% examples, 95947 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:51: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:51: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:51: EPOCH - 6 : training on 601119 raw words (219677 effective words) took 2.2s, 98207 effective words/s
# INFO - 09:32:52: EPOCH 7 - PROGRESS: at 44.72% examples, 97197 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:53: EPOCH 7 - PROGRESS: at 95.04% examples, 102219 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:53: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:53: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:53: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:53: EPOCH - 7 : training on 601119 raw words (219546 effective words) took 2.1s, 104312 effective words/s
# INFO - 09:32:54: EPOCH 8 - PROGRESS: at 50.05% examples, 104176 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:55: EPOCH 8 - PROGRESS: at 98.21% examples, 104226 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:55: EPOCH - 8 : training on 601119 raw words (219363 effective words) took 2.1s, 104661 effective words/s
# INFO - 09:32:56: EPOCH 9 - PROGRESS: at 40.98% examples, 90208 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:57: EPOCH 9 - PROGRESS: at 90.09% examples, 97705 words/s, in_qsize 1, out_qsize 0
# INFO - 09:32:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:57: EPOCH - 9 : training on 601119 raw words (219047 effective words) took 2.2s, 99255 effective words/s
# INFO - 09:32:58: EPOCH 10 - PROGRESS: at 44.72% examples, 95386 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:59: EPOCH 10 - PROGRESS: at 96.63% examples, 102650 words/s, in_qsize 0, out_qsize 0
# INFO - 09:32:59: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:32:59: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:32:59: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:32:59: EPOCH - 10 : training on 601119 raw words (219194 effective words) took 2.1s, 104683 effective words/s
# INFO - 09:33:00: EPOCH 11 - PROGRESS: at 42.87% examples, 93376 words/s, in_qsize 1, out_qsize 0
# INFO - 09:33:01: EPOCH 11 - PROGRESS: at 91.80% examples, 99385 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:01: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:01: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:01: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:01: EPOCH - 11 : training on 601119 raw words (219482 effective words) took 2.2s, 100166 effective words/s
# INFO - 09:33:03: EPOCH 12 - PROGRESS: at 44.72% examples, 95791 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:04: EPOCH 12 - PROGRESS: at 96.63% examples, 102921 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:04: EPOCH - 12 : training on 601119 raw words (219283 effective words) took 2.1s, 104696 effective words/s
# INFO - 09:33:05: EPOCH 13 - PROGRESS: at 48.35% examples, 103607 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:06: EPOCH 13 - PROGRESS: at 96.63% examples, 102807 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:06: EPOCH - 13 : training on 601119 raw words (219163 effective words) took 2.1s, 104633 effective words/s
# INFO - 09:33:07: EPOCH 14 - PROGRESS: at 50.05% examples, 105563 words/s, in_qsize 1, out_qsize 0
# INFO - 09:33:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:08: EPOCH - 14 : training on 601119 raw words (219808 effective words) took 2.0s, 108767 effective words/s
# INFO - 09:33:09: EPOCH 15 - PROGRESS: at 48.35% examples, 99552 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:10: EPOCH 15 - PROGRESS: at 98.21% examples, 102978 words/s, in_qsize 2, out_qsize 1
# INFO - 09:33:10: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:10: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:10: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:10: EPOCH - 15 : training on 601119 raw words (219285 effective words) took 2.1s, 103871 effective words/s
# INFO - 09:33:11: EPOCH 16 - PROGRESS: at 48.35% examples, 104314 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:12: EPOCH 16 - PROGRESS: at 100.00% examples, 109105 words/s, in_qsize 0, out_qsize 1
# INFO - 09:33:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:12: EPOCH - 16 : training on 601119 raw words (219332 effective words) took 2.0s, 109051 effective words/s
# INFO - 09:33:13: EPOCH 17 - PROGRESS: at 44.72% examples, 94562 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:14: EPOCH 17 - PROGRESS: at 90.09% examples, 96153 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:14: EPOCH - 17 : training on 601119 raw words (219136 effective words) took 2.3s, 96167 effective words/s
# INFO - 09:33:15: EPOCH 18 - PROGRESS: at 44.72% examples, 96516 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:16: EPOCH 18 - PROGRESS: at 90.09% examples, 97165 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:16: EPOCH - 18 : training on 601119 raw words (219590 effective words) took 2.2s, 97837 effective words/s
# INFO - 09:33:17: EPOCH 19 - PROGRESS: at 46.58% examples, 97224 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:18: EPOCH 19 - PROGRESS: at 90.09% examples, 96123 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:19: EPOCH - 19 : training on 601119 raw words (219133 effective words) took 2.3s, 96914 effective words/s
# INFO - 09:33:20: EPOCH 20 - PROGRESS: at 40.98% examples, 90117 words/s, in_qsize 1, out_qsize 0
# INFO - 09:33:21: EPOCH 20 - PROGRESS: at 84.97% examples, 92569 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:21: EPOCH - 20 : training on 601119 raw words (219339 effective words) took 2.3s, 94346 effective words/s
# INFO - 09:33:22: EPOCH 21 - PROGRESS: at 46.58% examples, 98199 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:23: EPOCH 21 - PROGRESS: at 91.80% examples, 97066 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:23: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:23: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:23: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:23: EPOCH - 21 : training on 601119 raw words (219370 effective words) took 2.2s, 98244 effective words/s
# INFO - 09:33:24: EPOCH 22 - PROGRESS: at 40.98% examples, 88142 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:25: EPOCH 22 - PROGRESS: at 90.09% examples, 95870 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:26: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:26: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:26: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:26: EPOCH - 22 : training on 601119 raw words (219411 effective words) took 2.3s, 97483 effective words/s
# INFO - 09:33:27: EPOCH 23 - PROGRESS: at 40.98% examples, 90579 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:28: EPOCH 23 - PROGRESS: at 88.44% examples, 94885 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:28: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:28: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:28: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:28: EPOCH - 23 : training on 601119 raw words (219541 effective words) took 2.3s, 96548 effective words/s
# INFO - 09:33:29: EPOCH 24 - PROGRESS: at 44.72% examples, 96912 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:30: EPOCH 24 - PROGRESS: at 88.44% examples, 95220 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:30: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:30: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:30: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:30: EPOCH - 24 : training on 601119 raw words (219026 effective words) took 2.3s, 96090 effective words/s
# INFO - 09:33:31: EPOCH 25 - PROGRESS: at 50.05% examples, 102408 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:32: EPOCH 25 - PROGRESS: at 88.44% examples, 93708 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:32: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:32: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:32: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:32: EPOCH - 25 : training on 601119 raw words (219369 effective words) took 2.4s, 92725 effective words/s
# INFO - 09:33:33: EPOCH 26 - PROGRESS: at 46.58% examples, 101160 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:34: EPOCH 26 - PROGRESS: at 96.63% examples, 105085 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:35: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:35: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:35: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:35: EPOCH - 26 : training on 601119 raw words (219095 effective words) took 2.1s, 106663 effective words/s
# INFO - 09:33:36: EPOCH 27 - PROGRESS: at 44.72% examples, 95437 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:37: EPOCH 27 - PROGRESS: at 96.63% examples, 103656 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:37: EPOCH - 27 : training on 601119 raw words (219584 effective words) took 2.1s, 105241 effective words/s
# INFO - 09:33:38: EPOCH 28 - PROGRESS: at 46.58% examples, 97031 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:39: EPOCH 28 - PROGRESS: at 93.44% examples, 96961 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:39: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:39: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:39: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:39: EPOCH - 28 : training on 601119 raw words (219753 effective words) took 2.3s, 97409 effective words/s
# INFO - 09:33:40: EPOCH 29 - PROGRESS: at 46.58% examples, 100579 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:41: EPOCH 29 - PROGRESS: at 96.63% examples, 103057 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:41: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:41: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:41: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:41: EPOCH - 29 : training on 601119 raw words (219058 effective words) took 2.1s, 105088 effective words/s
# INFO - 09:33:42: EPOCH 30 - PROGRESS: at 44.72% examples, 96606 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:43: EPOCH 30 - PROGRESS: at 90.09% examples, 95888 words/s, in_qsize 0, out_qsize 0
# INFO - 09:33:43: worker thread finished; awaiting finish of 2 more threads
# INFO - 09:33:43: worker thread finished; awaiting finish of 1 more threads
# INFO - 09:33:43: worker thread finished; awaiting finish of 0 more threads
# INFO - 09:33:43: EPOCH - 30 : training on 601119 raw words (219783 effective words) took 2.2s, 98454 effective words/s
# INFO - 09:33:43: training on a 18033570 raw words (6581170 effective words) took 65.7s, 100153 effective words/s
# Time to train the model: 1.1 mins

# %% [markdown]
# As we do not plan to train the model any further, we are calling init_sims(), which will make the model much more memory-efficient:

# %%
w2v_model.init_sims(replace=True)
# Out:
# INFO - 09:33:43: precomputing L2-norms of word weight vectors

# %% [markdown]
# # Exploring the model
# ## Most similar to:
#
# Here, we will ask our model to find the word most similar to some of the most iconic characters of the Simpsons!

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/0/02/Homer_Simpson_2006.png/revision/latest?cb=20091207194310" alt="drawing" width="130"/>
#
# Let's see what we get for the show's main character:

# %%
w2v_model.wv.most_similar(positive=["homer"])
# Out:
# [('depressed', 0.7398780584335327),
#  ('marge', 0.6910881400108337),
#  ('terrific', 0.6617944240570068),
#  ('bongo', 0.6588892936706543),
#  ('hammock', 0.6579198241233826),
#  ('suspicious', 0.6570777297019958),
#  ('sweetheart', 0.6524301171302795),
#  ('dr_hibbert', 0.6502234935760498),
#  ('reverend_lovejoy', 0.6424009799957275),
#  ('crummy', 0.6420508027076721)]

# %% [markdown]
# _A small precision here:_<br>
# The dataset is the Simpsons' lines of dialogue; therefore, when we look at the most similar words from "homer" we do **not** necessary get his family members, personality traits, or even his most quotable words. No, we get what other characters (as Homer does not often refers to himself at the 3rd person) said along with "homer", such as how he feels or looks ("depressed"), where he is ("hammock"), or with whom ("marge").
#
# Let's see what the bigram "homer_simpson" gives us by comparison:

# %%
w2v_model.wv.most_similar(positive=["homer_simpson"])
# Out:
# [('congratulation', 0.7120206356048584),
#  ('client', 0.7011325359344482),
#  ('governor', 0.6790627241134644),
#  ('pleased', 0.6787175536155701),
#  ('sir', 0.6775203943252563),
#  ('select', 0.6770873069763184),
#  ('kidnap', 0.6680606603622437),
#  ('easily', 0.6655595302581787),
#  ('hutz', 0.6601171493530273),
#  ('current', 0.6581157445907593)]

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/0/0b/Marge_Simpson.png/revision/latest?cb=20180626055729" alt="drawing" width="150"/>
#
# What about Marge now?

# %%
w2v_model.wv.most_similar(positive=["marge"])
# Out:
# [('homie', 0.7049174308776855),
#  ('becky', 0.6986762285232544),
#  ('arrange', 0.6976852416992188),
#  ('grownup', 0.6937166452407837),
#  ('homer', 0.6910881400108337),
#  ('anyhoo', 0.6895078420639038),
#  ('badly', 0.6851606369018555),
#  ('rude', 0.6807416081428528),
#  ('fault', 0.6725369095802307),
#  ('honey', 0.670545220375061)]

# %% [markdown]
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/6/65/Bart_Simpson.png/revision/latest?cb=20180319061933" alt="drawing" width="100"/>
#
# Let's check Bart now:

# %%
w2v_model.wv.most_similar(positive=["bart"])
# Out:
# [('lisa', 0.8286843299865723),
#  ('dr_hibbert', 0.745305597782135),
#  ('homework', 0.7366843223571777),
#  ('mom_dad', 0.7329127192497253),
#  ('upset', 0.7289363145828247),
#  ('hearing', 0.7264739274978638),
#  ('mom', 0.726322591304779),
#  ('creepy', 0.7235132455825806),
#  ('strangle', 0.6947540640830994),
#  ('surprised', 0.6929579377174377)]

# %% [markdown]
# Looks like it is making sense!
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/9/9d/Groundskeeper_Willie.png/revision/latest?cb=20130424154035" alt="drawing" width="150"/>
#
# Willie the groundskeeper for the last one:

# %% [markdown]
# ## Similarities:
# Here, we will see how similar are two words to each other :

# %%
w2v_model.wv.similarity("moe_'s", 'tavern')
# Out:
# 0.9162540256213707

# %% [markdown]
# Who could forget Moe's tavern? Not Barney.
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/6/6c/MaggieSimpson.PNG/revision/latest?cb=20180314210204" alt="drawing" width="100"/>

# %%
w2v_model.wv.similarity('maggie', 'baby')
# Out:
# 0.6956055625095678

# %% [markdown]
# Maggie is indeed the most renown baby in the Simpsons!

# %%
w2v_model.wv.similarity('bart', 'nelson')
# Out:
# 0.5577130131432233

# %% [markdown]
# Bart and Nelson, though friends, are not that close, makes sense!
#
# ## Odd-One-Out:
#
# Here, we ask our model to give us the word that does not belong to the list!
#
# Between Jimbo, Milhouse, and Kearney, who is the one who is not a bully?

# %%
w2v_model.wv.doesnt_match(['jimbo', 'milhouse', 'kearney'])
# Out:
# 'milhouse'

# %% [markdown]
# Milhouse of course!
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/9/91/Milhouse_Van_Houten_2.png/revision/latest?cb=20180429212659" alt="drawing" width="150"/>
#
# What if we compared the friendship between Nelson, Bart, and Milhouse?

# %%
w2v_model.wv.doesnt_match(["nelson", "bart", "milhouse"])
# Out:
# 'nelson'

# %% [markdown]
# Seems like Nelson is the odd one here!
#
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/4/40/Picture0003.jpg/revision/latest?cb=20110623042517" alt="drawing" width="200"/>
#
# Last but not least, how is the relationship between Homer and his two sister-in-laws?

# %%
w2v_model.wv.doesnt_match(['homer', 'patty', 'selma'])
# Out:
# 'homer'

# %% [markdown]
# Damn, they really do not like you Homer!
#
# ## Analogy difference:
# Which word is to woman as homer is to marge?

# %%
w2v_model.wv.most_similar(positive=["woman", "homer"], negative=["marge"], topn=3)
# Out:
# [('man', 0.6467181444168091),
#  ('attractive', 0.5829726457595825),
#  ('people', 0.563256025314331)]

# %% [markdown]
# "man" comes at the first position, that looks about right!
#
# Which word is to woman as bart is to man?

# %%
w2v_model.wv.most_similar(positive=["woman", "bart"], negative=["man"], topn=3)
# Out:
# [('lisa', 0.6884287595748901),
#  ('assignment', 0.6289387941360474),
#  ('parent', 0.6223844885826111)]

# %% [markdown]
# Lisa is Bart's sister, her male counterpart!
# <img src="https://vignette.wikia.nocookie.net/simpsons/images/5/57/Lisa_Simpson2.png/revision/latest?cb=20180319000458" alt="drawing" width="100"/>

# %% [markdown]
# ### t-SNE visualizations:
# t-SNE is a non-linear dimensionality reduction algorithm that attempts to represent high-dimensional data and the underlying relationships between vectors in a lower-dimensional space.<br>
# Here is a good tutorial on it: https://medium.com/@luckylwk/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
import seaborn as sns
sns.set_style("darkgrid")

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# Our goal in this section is to plot our 300 dimensions vectors into 2 dimensional graphs, and see if we can spot interesting patterns.<br>
# For that we are going to use t-SNE implementation from scikit-learn.
#
# To make the visualizations more relevant, we will look at the relationships between a query word (in <font color='red'>**red**</font>), its most similar words in the model (in <font color="blue">**blue**</font>), and other words from the vocabulary (in <font color='green'>**green**</font>).

# %%
def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=50).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %% [markdown]
# Code inspired by: [[2]](#References:)
#
# ## 10 Most similar words vs. 8 Random words:
# Let's compare where the vector representation of Homer, his 10 most similar words from the model, as well as 8 random ones, lies in a 2D graph:

# %%
tsnescatterplot(w2v_model, 'homer', ['dog', 'bird', 'ah', 'maude', 'bob', 'mel', 'apu', 'duff'])

# %% [markdown]
# Interestingly, the 10 most similar words to Homer ends up around him, so does Apu and (sideshow) Bob, two recurrent characters.
#
# ## 10 Most similar words vs. 10 Most dissimilar
#
# This time, let's compare where the vector representation of Maggie and her 10 most similar words from the model lies compare to the vector representation of the 10 most dissimilar words to Maggie:

# %%
tsnescatterplot(w2v_model, 'maggie', [i[0] for i in w2v_model.wv.most_similar(negative=["maggie"])])

# %% [markdown]
# Neat! Maggie and her most similar words form a distinctive cluster from the most dissimilar words, it is a really encouraging plot!
#
# ## 10 Most similar words vs. 11th to 20th Most similar words:
#
# Finally, we are going to plot the most similar words to Mr. Burns ranked 1st to 10th versus the ones ranked 11th to 20th:
#
# (PS: Mr. Burns became mr_burn after the preprocessing)

# %%
tsnescatterplot(w2v_model, "mr_burn", [t[0] for t in w2v_model.wv.most_similar(positive=["mr_burn"], topn=20)][10:])

# %% [markdown]
# As we can see, and that is very nice, all the 20 words are forming one cluster around Mr. Burns.
#
# # Final Thoughts
#
# I hope you found this tutorial useful and had as much fun reading it as I had writing it. Please do not hesitate to leave any comments, questions or suggestions you might have. See you around!
#
# Also, please check [Supportiv](http://www.supportiv.com) around! (Simpson-ized logo)
#
# <img src="https://fontmeme.com/permalink/180904/cc3d27a8aaa88189e764ee9d02331d0d.png" alt="drawing" width="500"/>
#
#
# # Materials for more in depths understanding:
# * Word Embeddings introduction: https://www.analyticsvidhya.com/blog/2017/06/word-embeddings-count-word2veec/
# * Word2Vec introduction: https://skymind.ai/wiki/word2vec
# * Another Word2Vec introduction: http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
# * A great Gensim implentation tutorial: http://kavita-ganesan.com/gensim-word2vec-tutorial-starter-code/#.W467ScBjM2x
# * Original articles from Mikolov et al.: https://arxiv.org/abs/1301.3781 and https://arxiv.org/abs/1310.4546
#
#
# # Acknowledgements
#
# * [Pouria Mojabi](https://www.linkedin.com/in/pouria-mojabi-1873615/), co-fouder of Supportiv Inc.
#
# # References:
# * [1]. Neural Net picture: McCormick, C. (2016, April 19). Word2Vec Tutorial - The Skip-Gram Model. Retrieved from http://www.mccormickml.com
# * [2]. Aneesha Bakharia Medium article: https://medium.com/@aneesha/using-tsne-to-plot-a-subset-of-similar-words-from-word2vec-bb8eeaea6229
#
# # End
